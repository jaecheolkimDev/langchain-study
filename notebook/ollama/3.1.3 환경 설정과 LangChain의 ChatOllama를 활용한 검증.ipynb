# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in e:\pycharm_workspace\langchain-study\venv\lib\site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -q python-dotenv langchain-ollama
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma2")

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '안녕하세요! 인프런에는 매우 다양한 분야의 강의들이 있어요. 몇 가지 주요 카테고리와 인기 있는 강의 예시를 알려드릴게요. \n\n**💻 IT & 프로그래밍:**\n\n* **웹 개발:** HTML, CSS, JavaScript, React, Node.js 등으로 웹사이트 제작을 배우실 수 있습니다. \n    * 예시: "0 to 1로 React 개발자 되기", "파이썬으로 웹 애플리케이션 만들기"\n* **앱 개발:** Android, iOS, Flutter 등으로 모바일 앱을 개발하는 강의가 많습니다.\n    * 예시: "Kotlin 기반 안드로이드 개발 완벽 가이드", "Swift로 iOS 앱 개발하기"\n* **데이터 과학 & 머신러닝:** Python, R, TensorFlow 등 데이터 분석 및 머신러닝 기술을 배우실 수 있습니다.\n    * 예시: "Python 머신러닝 실전 가이드", "머신러닝 알고리즘 이해하기"\n\n**💡 디자인 & 창작:**\n\n* **그래픽 디자인:** Photoshop, Illustrator 등 사용법과 디자인 원리를 배울 수 있습니다.\n    * 예시: "초보자도 1달 만에 마스터하는 Photoshop 기본", "일러스트로 로고 디자인하기"\n* **웹 디자인:** 웹사이트를 직접 디자인하고 제작하는 강의가 있습니다.\n    * 예시: "WordPress로 블로그 & 웹사이트 만들기", "Figma 디자인으로 UX/UI 전문가 되기"\n* **사진 & 영상 편집:** Adobe Premiere Pro, After Effects 등을 사용하여 사진 및 영상 편집 기술을 배우실 수 있습니다.\n    * 예시: "초보자를 위한 아메리칸 프리미어 프로 강의", "After Effects로 동영상 효과 만들기"\n\n**💼 직업 & 경력 개발:**\n\n* ** PMP, 6 sigma 등 전문 자격증 학습:** IT 관련 전문 지식을 심화하는 방법으로 인프런에서 다양한 자격증 과정이 제공됩니다.\n* **소통 및 리더십 강의:** 효과적인 커뮤니케이션 기술과 리더십 역량을 개발할 수 있습니다.\n    * 예시: "명상 & 스트레스 관리", "우리팀, 우리가 만들다"\n\n**📚 학문 & 문화:**\n\n* **외국어 학습:** 영어, 중국어, 일본어 등 다양한 외국어를 배우실 수 있습니다.\n    * 예시: "TOEIC 실전 대비 파워 코스", "중국어 1부터 시작하기"\n* **역사, 철학, 문화:** 역사적 사건과 사상을 이해하고 문화적 지식을 넓힐 수 있는 강의가 있습니다.\n    * 예시: "조선 시대 이야기", "인문학 기초 다지기"\n\n**✨ 자세한 정보는 인프런 웹사이트를 방문하거나 인프런 앱을 이용해 확인하세요! ✨**\n\n\n'
